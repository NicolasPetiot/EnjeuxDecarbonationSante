# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasPetiot/EnjeuxDecarbonationSante/blob/main/setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup:
#
# Ce TP est pensé pour être 100% faisable sur [Google Colab](https://colab.research.google.com/). Cependant, il est possible d'installer les différentes dépendances localement (voir section **Setup Local**).

# %%
import sys
if not "google.colab" in sys.modules:
    raise EnvironmentError("Cette cellule doit être exécuté depuis un environement Google Colab")

from google.colab import drive
drive.mount('/content/drive')

# !pip install pyrosetta-installer
from pyrosetta_installer import install_pyrosetta
install_pyrosetta()
# Out:
#   File "/tmp/ipykernel_5442/1746667410.py", line 13
#     cd /content/drive/MyDrive/
#                               ^
# SyntaxError: invalid syntax

# %%
# %%bash
# cd /content/drive/MyDrive/
# git clone https://github.com/NicolasPetiot/EnjeuxDecarbonationSante.git
# Out:
# Cloning into 'EnjeuxDecarbonationSante'...

# %% [markdown]
# # Setup Local:
#
# Ce TP est basé sur la librairie [`pyrosetta`](https://www.pyrosetta.org/downloads#h.yscr0432xlk9) et il existe plusieurs méthodes d'installation. Le plus simple étant d'utiliser le pyrosetta installer
#
# **N.B.**: Pour les utilisateurs de Windows, PyRosetta doit nécessairement être installé sur le Windows Subsystem for Linux (WSL)

# %%
git clone git@github.com:NicolasPetiot/EnjeuxDecarbonationSante.git

pip install pyrosetta-installer
pip install numpy matplotlib pandas scipy tqdm # Autres dépendances

# %%
from pyrosetta_installer import install_pyrosetta
install_pyrosetta()
